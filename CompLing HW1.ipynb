# %% [markdown]
# # Домашнее задание № 1

# %% [markdown]
# ## 1. Задание на удаление тегов (2 балла)

# %% [markdown]
# Часто в данных, с которыми нам нужно работать помимо текста присутствует ещё какая-то лишняя информация: тэги, ссылки, код, разметка. Она, конечно, не всегда лишняя, но обычно от неё лучше избавиться.

# %% [markdown]
# Возьмем в качестве примера статью с Хабрахабра. Она скачана автоматически и в там остались некоторые тэги.

# %%
# !pip install pymystem3
# !pip install pymorphy2[fast]
# !pip install razdel
# !pip install genism
# !pip install regex
# Out:
# Collecting pymystem3
#   Downloading pymystem3-0.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from pymystem3) (2.25.1)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0
# Requirement already satisfied: pymorphy2[fast] in /home/daria/.local/lib/python3.9/site-packages (0.9.1)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /home/daria/.local/lib/python3.9/site-packages (from pymorphy2[fast]) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /home/daria/.local/lib/python3.9/site-packages (from pymorphy2[fast]) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /home/daria/.local/lib/python3.9/site-packages (from pymorphy2[fast]) (0.7.2)
# Requirement already satisfied: DAWG>=0.8 in /home/daria/.local/lib/python3.9/site-packages (from pymorphy2[fast]) (0.8.0)
# Collecting razdel
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Installing collected packages: razdel
#   WARNING: The script razdel-ctl is installed in '/home/daria/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed razdel-0.5.0
# ERROR: Could not find a version that satisfies the requirement genism
# ERROR: No matching distribution found for genism
# Collecting regex
#   Downloading regex-2021.11.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#      |████████████████████████████████| 762 kB 1.4 MB/s eta 0:00:01
# Installing collected packages: regex
# Successfully installed regex-2021.11.2

# %%
text = '''
Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>. Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично!<br><br><img src="http://img172.imageshack.us/img172/8434/18274658kc4.png" alt="Сумасшедшее яйцо"><br><br><blockquote><h3>Что это такое?</h3><br>
Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.<br>
Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые).<br><br><img src="https://habrastorage.org/getpro/habr/post_images/7c7/298/33c/7c729833cd942cc493e68833e3e0f12d.jpg" alt="Тепловое отслеживание популярности"><br></blockquote><br><br><a name="habracut"></a><br><br><blockquote><h3>Для кого это?</h3><br>
Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0b0/0a0/b16/0b00a0b16b1eda28e35f39487dcd2545.jpg" alt="Отслеживание ссылок"></blockquote><br><blockquote><img src="https://habrastorage.org/getpro/habr/post_images/0b5/433/892/0b54338921665ffb5a90930147296f5b.jpg" alt="Список по популярности"><br><br>
Да-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса).</blockquote><br><blockquote><h3>Зачем это?</h3><br>
С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет <a href="http://ttp://www.crazyegg.com" title="Сумасшедшие яйца">Сумасшедшее яйцо</a>.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/38c/af8/e75/38caf8e753782a01dc6419d3902edd57.jpg" alt="Добавление проекта"></blockquote><br><blockquote>Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователей.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/0dd/3fb/b34/0dd3fbb34709e77f3fbcd6523c7eac77.jpg" alt="еще полезности"></blockquote><br><blockquote><h3>Как это работает?</h3><br>
Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере <a href="http://www.crazyegg.com" title="Сумасшедшие яйца">CrazyEgg</a>, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки большая.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/a90/e4e/e67/a90e4ee6760978463e6306a2f5982e24.jpg" alt="управление популярностью"></blockquote><br><blockquote><h3>Сколько это стоит?</h3><br>
Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации.</blockquote><br><blockquote>1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.<br><br>
2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции.<br><br>
3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.<br><br>
4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются.<br><br>
5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страниц.<br><br><img src="https://habrastorage.org/getpro/habr/post_images/f73/fb2/62d/f73fb262da4618a8dde67690cfd191ea.jpg" alt="Отслеживание статистики"></blockquote><br><blockquote><h3>Есть и аналоги</h3><br>
Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле.</blockquote><br><blockquote> 1. <a href="https://www.google.com/analytics/home/?hl=en" title="Шикарный сбор и анализ статистики">Google Analytics</a> — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользуюсь им для этого блога.<br><br>
2. <a href="http://www.mapsurface.com/" title="Сервис для отслеживания популярности блоков на сайте">MapSurface</a> — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов. К сожалению он сейчас находится в статусе закрытой беты.</blockquote><br><blockquote><h3>Вывод</h3><br>
Использовать можно, и нужно. Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги. Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию. В общем и целом — <a href="http://ttp://www.crazyegg.com">полезная вещь</a> для каждого владельца сайтов, а для юзабилиста вообще практически обязательна. К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.<br><br><img src="http://img241.imageshack.us/img241/2346/confettitnml5.jpg" alt="Интересная идея визуализации популярности - конфети"></blockquote><br><br>
Автор: <a href="http://www.birzool.com/" title="Я пишу о юзабилити веб интерфейсов">Ярослав Бирзул</a> (DezmASter).<br>
Источник: <a href="http://www.birzool.com/crazyegg/" title="Сумасшедшие яйца, первоисточник">Блог о юзабилити веб интерфейсов</a>.<br><br>
PS: Всех с прошедшим Новым годом! От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах. Удачно вам провести время.
'''

# %%
import re

# %%
def remove_tags(a):
    a = re.sub('<.+?>', '', text)
    b = re.sub('.(\.)([А-Я])', r'\1 \2', a)
    return b
    # remove tags

# %%
text = remove_tags(text)
print(text)
# Out:
# Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg. Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. Запоминается? Отлично!Что это такое?
# Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.
# Сервис позволяет отслеживать активность определенных пользователей, и выводить эти данные в различных формах: «инфракрасная» — где чем активнее область, тем она «теплее», салюты (чем активнее область, тем больше конфети), простой список с сортировкой по активности, колбы (чем заполненнее колба, тем активнее область), облака (на мой взгляд наиболее удобный вариант — совмещает в себе все остальные вместе взятые. Для кого это?
# Разумеется сервис изначально планировался как первый помощник для юзабилистов, но пользоваться им может каждый, у кого есть деньги — интуитивный интерфейс, и хороший дизайн дает о себе знать — сервис массово популяризировался пол года-год назад. Относительно недорогой, но уж точно не из дешевых — сервис предполагает собой 4 платных линии и одну бесплатную. Дабы написать этот обзор я не поленился заплатить 19 долларов (в месяц) выбрав средний вариант — для нескольких проектов с включенными дополнительными функциями.
# Да-да, сервис не бесплатен. Точнее бесплатная возможность потестировать есть, но она немного обрезана (можно отслеживать только 5000 посетителей и всего 4 страницы на сайте (внимание — 4 страницы, а не сайтов), т.е. вполне хватает для того, чтобы понять полезность сервиса. Зачем это?
# С помощью этого сервиса можно тасовать блоки на сайте, которые полезны пользователям больше всего. Больше не нужно спорить создателям — какой блок где расположить. В этом им поможет Сумасшедшее яйц. Также этот сервис поможет вам понять — в какой зоне сайта лучше всего располагать рекламу, когда в вашем сервисе речь зайдет о монетизации. Ведь альтруизм это хорошо, а деньги на содержание сервиса нужны, и не лишним будет вычислить зоны где реклама будет приносить наибольшую отдачу, и наименьшее раздражение у пользователе. Как это работает?
# Никаких километровых скриптов вставлять не нужно, достаточно вставиь 2 строчки яваскрипта, и сервис начнет отслеживание. Насколько я понял — исполнительный скрипт работает на сервере CrazyEgg, поэтому ваш сайт от этого в производительности не потеряет ни секунды, а полезность довольно таки больша. Сколько это стоит?
# Как я уже упоминал — сервис далеко не бесплатен, хоть и имеет тестовую-бесплатную версию. Расскажу подробнее о тарификации.1. Бесплатная тестовая версия. Включает в себя возможность отслеживания 5 000 посещений, 4 страницы на сайте.
# 2. Базовая версия. В этой версии можно отследить 10 000 посещений, и 10 страниц, что вполне достаточно для среднего корпоративного сайта. Стоит базовый комплект — 9 долларов в месяц. В этот комплект включены все дополнительные функции.
# 3. Версия «Стандарт». В неё входит возможность отслеживания 25 000 посещений на 20 страницах. Вполне подходит для тестирования нового стартапа. Стоит она 19 долларов в месяц, именно её я купил для тестирования сервиса, и написания этого обзора.
# 4. Версия «Плюс». Отличается от предыдущей возможностью отслеживания 100 000 посещений, 50 страниц. Очень хороший тариф для крупных сервисов. Стоит 49 долларов в месяц. Довольно большие деньги за сервис, но они обычно с лихвой окупаются.
# 5. Версия «Про». Стоит почти 100 долларов, имеет возможность отследить 250 000 посещений на ста страницах. Тариф подходит для монстров с большой посещаемостью и большим количеством страни. Есть и аналоги
# Я не поленился, и собрал еще пару ссылок с аналогами, которые предлагают такие же услуги, но немного дешевле. 1. Google Analytics — бесплатный сервис для сбора и анализа статистики, вывод статистики в наиболее наглядной форме, и без разнообразных рейтингов, счетчиков. Очень подробная и полезная вещь. Рекомендую, т.к. сам пользуюсь им для этого блога.
# 2. MapSurface — сам еще не использовал (т.к. предпочел CrazyEgg), но врядли будучи плохим сервис собрал бы множество положительных отзывов. К сожалению он сейчас находится в статусе закрытой бет. Вывод
# Использовать можно, и нужно. Вот только тарифы довольно больно кусаются, но обычно эти деньги потом с лихвой отбиваются на повышении конвертации посетителей в деньги. Использовать сервис нужно для тестирования рекламных мест и удобства отдельных страниц, что помогает опять же повысить конвертацию. В общем и целом — полезная вещь для каждого владельца сайтов, а для юзабилиста вообще практически обязательна. К счастью для людей, которые поиздержались деньгами в этом месяце — есть полезные аналоги.
# Автор: Ярослав Бирзул (DezmASter).
# Источник: Блог о юзабилити веб интерфейсов.
# PS: Всех с прошедшим Новым годом! От всей души желаю вам всего самого-самого лучшего, чего вы желаете только в самых сокровенных мечтах. Удачно вам провести время.

# %% [markdown]
# С помощью регулярных выражение очистите текст от тэгов (мета информацию внутри тэгов тоже удалите). В получившемся тексте точки не должны слипаться с началом следующего предложений, также не должно быть лишних пробелов.

# %% [markdown]
# ## 2. Задание на выбор слов после "не " (1 балл)
#
# Вытащите из очищенного текста все слова, которые идут после "не ", кроме слов, начинающихся на гласную букву. Сама часть "не " не должна извлекаться.

# %%
re.findall('не ([^а, о, у, ы, е, я, э, ю, и]\w+)', text)
# Out:
# ['знаю',
#  'поленился',
#  'бесплатен',
#  'сайтов',
#  'хватает',
#  'нужно',
#  'сайта',
#  'лишним',
#  'нужно',
#  'потеряет',
#  'бесплатен',
#  'достаточно',
#  'подходит',
#  'поленился']

# %% [markdown]
# ## 3. Задание на выбор глаголов (1 балл)
#
# Попробуйте вытащить из очищенного текста как можно больше глаголов (минимум 40 с повоторениями), не перечисляя их в паттерне полностью. Можете токенизировать текст и использовать re.match, а можете использовать re.findall с \\b в начале и конце паттерна, чтобы не матчить части слов.
#
# В результате не должно быть не глаголов. Также постарайтесь сделать паттерн максимально коротким.

# %%
re.findall((r'\b\w+[иа]ть\b|\b\w+ся\b|\b\w+ет\b'), text)
# Out:
# ['будет',
#  'работает',
#  'Запоминается',
#  'позволяет',
#  'отслеживать',
#  'выводить',
#  'совмещает',
#  'Разумеется',
#  'планировался',
#  'пользоваться',
#  'может',
#  'дает',
#  'знать',
#  'популяризировался',
#  'предполагает',
#  'написать',
#  'поленился',
#  'заплатить',
#  'потестировать',
#  'отслеживать',
#  'хватает',
#  'тасовать',
#  'спорить',
#  'расположить',
#  'поможет',
#  'поможет',
#  'располагать',
#  'зайдет',
#  'будет',
#  'вычислить',
#  'будет',
#  'приносить',
#  'работает',
#  'начнет',
#  'работает',
#  'потеряет',
#  'имеет',
#  'Включает',
#  'отследить',
#  'Отличается',
#  'окупаются',
#  'имеет',
#  'отследить',
#  'поленился',
#  'находится',
#  'бет',
#  'Использовать',
#  'кусаются',
#  'отбиваются',
#  'Использовать',
#  'помогает',
#  'повысить']

# %%
len(re.findall((r'\b\w+[иа]ть\b|\b\w+ся\b|\b\w+ет\b'), text))
# Out:
# 52

# %% [markdown]
# ## 4. Pymorphy vs Mystem (2 балла)

# %% [markdown]
# Лемматизируйте очищенный текст с помощью mystem и pymorphy. Сравните результаты: есть ли разница, что лучше.

# %% [markdown]
# Для пайморфи используйте токенизацию из mystem, чтобы исключить влияние токенизации на результат.

# %%
from pymystem3 import Mystem
import os, json
mystem = Mystem()
# Out:
# Installing mystem to /home/daria/.local/bin/mystem from http://download.cdn.yandex.net/mystem/mystem-3.1-linux-64bit.tar.gz

# %%
# Лемматизация Mystem

mystem.lemmatize(text)[:15]
# Out:
# ['\n',
#  'сегодняшний',
#  ' ',
#  'заметка',
#  ' ',
#  'быть',
#  ' ',
#  'о',
#  ' ',
#  'сервис',
#  ' ',
#  'отслеживание',
#  ' ',
#  'активность',
#  ' ']

# %%
words_analyzed = mystem.analyze(text)
words_analyzed[:15]
# Out:
# [{'text': '\n'},
#  {'analysis': [{'lex': 'сегодняшний', 'wt': 1, 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'Сегодняшняя'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'заметка', 'wt': 1, 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'заметка'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'быть',
#     'wt': 0.1492564349,
#     'gr': 'V,нп=непрош,ед,изъяв,3-л'}],
#   'text': 'будет'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'о', 'wt': 0.9737875835, 'gr': 'PR='}], 'text': 'о'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сервис', 'wt': 1, 'gr': 'S,муж,неод=пр,ед'}],
#   'text': 'сервисе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отслеживание',
#     'wt': 1,
#     'gr': 'S,сред,неод=(вин,мн|род,ед|им,мн)'}],
#   'text': 'отслеживания'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активность',
#     'wt': 1,
#     'gr': 'S,жен,неод=(пр,ед|вин,мн|дат,ед|род,ед|им,мн)'}],
#   'text': 'активности'},
#  {'text': ' '}]

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize, wordpunct_tokenize
# Out:
# Requirement already satisfied: nltk in /home/daria/.local/lib/python3.9/site-packages (3.6.5)
# Requirement already satisfied: regex>=2021.8.3 in /home/daria/.local/lib/python3.9/site-packages (from nltk) (2021.11.2)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /home/daria/.local/lib/python3.9/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: joblib in /home/daria/.local/lib/python3.9/site-packages (from nltk) (1.1.0)
# [nltk_data] Downloading package punkt to /home/daria/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Лемматизация Pymorphy

from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()

words_analyzed = [morph.parse(token) for token in word_tokenize(text)]
print(words_analyzed[0:3])
# Out:
# [[Parse(word='сегодняшняя', tag=OpencorporaTag('ADJF femn,sing,nomn'), normal_form='сегодняшний', score=1.0, methods_stack=((DictionaryAnalyzer(), 'сегодняшняя', 493, 7),))], [Parse(word='заметка', tag=OpencorporaTag('NOUN,inan,femn sing,nomn'), normal_form='заметка', score=1.0, methods_stack=((DictionaryAnalyzer(), 'заметка', 8, 0),))], [Parse(word='будет', tag=OpencorporaTag('VERB,impf,intr sing,3per,futr,indc'), normal_form='быть', score=1.0, methods_stack=((DictionaryAnalyzer(), 'будет', 620, 12),))]]

# %%
print('Первое слово - ', words_analyzed[0][0].word)
print('Разбор первого слова - ', words_analyzed[0][0])
print('Лемма первого слова - ', words_analyzed[0][0].normal_form)
print('Грамматическая информация первого слова - ', words_analyzed[0][0].tag)
print('Часть речи первого слова - ', words_analyzed[0][0].tag.POS)
print('Род первого слова - ', words_analyzed[0][0].tag.gender)
print('Число первого слова - ', words_analyzed[0][0].tag.number)
print('Падеж первого слова - ', words_analyzed[0][0].tag.case)
# Out:
# Первое слово -  сегодняшняя
# Разбор первого слова -  Parse(word='сегодняшняя', tag=OpencorporaTag('ADJF femn,sing,nomn'), normal_form='сегодняшний', score=1.0, methods_stack=((DictionaryAnalyzer(), 'сегодняшняя', 493, 7),))
# Лемма первого слова -  сегодняшний
# Грамматическая информация первого слова -  ADJF femn,sing,nomn
# Часть речи первого слова -  ADJF
# Род первого слова -  femn
# Число первого слова -  sing
# Падеж первого слова -  nomn

# %% [markdown]
# **Обе библиотеки лемматизируют текст с примерно одинаковой точностью.
# Однако Mystem позволяет работать с текстом без предварительной токенизации, что делает его удобнее в использовании.**

# %% [markdown]
# ## 5. Разбиение на предложения в Mystem (2 балла)
#
# С помощью Mystem разделите текст из первого задания (очищенный) на предложения. Сравните разбиение с razdel.sentenize

# %%
with open ('text.txt', 'w+') as f:
    f.write(text)

# %%
# !./mystem -sc --format json text.txt text_parsed.txt

# %%
import json
t = [json.loads(line) for line in open('text_parsed.txt')]

# %%
from operator import concat
from functools import reduce
from itertools import chain

# %%
list(
    chain( #сглаживание списка
        *map(lambda item: item.split('\\s'), #разделение по \\s
            map(lambda item: ''.join( #выделение и объединение
                map(lambda item: item['text'], item)),
                t 
            )
        )
    )
)[:5]
# Out:
# ['\n',
#  'Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg. ',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо. ',
#  'Запоминается? ',
#  'Отлично!Что это такое?\n']

# %%
from razdel import sentenize
sents = list(sentenize(text))
[sent.text for sent in sents[:5]]
# Out:
# ['Сегодняшняя заметка будет о сервисе отслеживания активности пользователя — CrazyEgg.',
#  'Я не знаю кому обязан сервис таким говорящим именем, но оно работает, и хорошо.',
#  'Запоминается?',
#  'Отлично!Что это такое?',
#  'Как уже сказано выше это сервис для отслеживания перемещения пользователей по сайту — кто куда кликнул, какие ссылки наиболее популярные и тому подобная, разнородная информация для юзабилистов.']

# %% [markdown]
# ## __Комментарий__
#
# **Разделение на предложения с Mystem** сложнее применимо, требует написания дополнительных функций.
#
# **Разделение с razdel** выполняется попроще и возвращает ровно тот же результат, что и Mystem.

# %% [markdown]
# ## 6*. Дизамбигуация в Mystem (2 балла)

# %% [markdown]
# *необязательное задание на 10 баллов

# %% [markdown]
# Одна из фичей майстема - контекстная дизамбигуация (т.е. определение правильного разбора в зависимости от контекста).

# %% [markdown]
# Запустите mystem на очищенном тексте с дизамбигуацией и без и проверьте есть ли какие-то различия.

# %% [markdown]
# ## **Разбор без дисамбигуации**

# %%
# !./mystem -isc --format json text.txt text_parsed.txt

import json
t = [json.loads(line) for line in open('text_parsed.txt')]
t[3]
# Out:
# [{'analysis': [{'lex': 'сервис', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'сервис', 'gr': 'S,муж,неод=им,ед'}],
#   'text': 'Сервис'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'позволять', 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}],
#   'text': 'позволяет'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отслеживать', 'gr': 'V=инф,несов,пе'}],
#   'text': 'отслеживать'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активность', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'активность'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'определенный', 'gr': 'A=пр,мн,полн'},
#    {'lex': 'определенный', 'gr': 'A=вин,мн,полн,од'},
#    {'lex': 'определенный', 'gr': 'A=род,мн,полн'},
#    {'lex': 'определять', 'gr': 'V,пе=прош,пр,мн,прич,полн,сов,страд'},
#    {'lex': 'определять', 'gr': 'V,пе=прош,вин,мн,прич,полн,сов,страд,од'},
#    {'lex': 'определять', 'gr': 'V,пе=прош,род,мн,прич,полн,сов,страд'}],
#   'text': 'определенных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пользователь', 'gr': 'S,муж,од=вин,мн'},
#    {'lex': 'пользователь', 'gr': 'S,муж,од=род,мн'}],
#   'text': 'пользователей'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'и', 'gr': 'CONJ='},
#    {'lex': 'и', 'gr': 'INTJ='},
#    {'lex': 'и', 'gr': 'S,сокр=пр,мн'},
#    {'lex': 'и', 'gr': 'S,сокр=пр,ед'},
#    {'lex': 'и', 'gr': 'S,сокр=вин,мн'},
#    {'lex': 'и', 'gr': 'S,сокр=вин,ед'},
#    {'lex': 'и', 'gr': 'S,сокр=дат,мн'},
#    {'lex': 'и', 'gr': 'S,сокр=дат,ед'},
#    {'lex': 'и', 'gr': 'S,сокр=род,мн'},
#    {'lex': 'и', 'gr': 'S,сокр=род,ед'},
#    {'lex': 'и', 'gr': 'S,сокр=твор,мн'},
#    {'lex': 'и', 'gr': 'S,сокр=твор,ед'},
#    {'lex': 'и', 'gr': 'S,сокр=им,мн'},
#    {'lex': 'и', 'gr': 'S,сокр=им,ед'},
#    {'lex': 'и', 'gr': 'PART='}],
#   'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'выводить', 'gr': 'V=инф,несов,пе'},
#    {'lex': 'вывести', 'gr': 'V,сов=инф,пе'},
#    {'lex': 'выводить', 'gr': 'V,сов,пе=инф'}],
#   'text': 'выводить'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'этот', 'gr': 'APRO=им,мн'},
#    {'lex': 'этот', 'gr': 'APRO=вин,мн,неод'}],
#   'text': 'эти'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'данные', 'gr': 'S,мн,неод=вин'},
#    {'lex': 'данные', 'gr': 'S,мн,неод=им'},
#    {'lex': 'давать', 'gr': 'V,пе=прош,вин,мн,прич,полн,сов,страд,неод'},
#    {'lex': 'давать', 'gr': 'V,пе=прош,им,мн,прич,полн,сов,страд'},
#    {'lex': 'данный', 'gr': 'A,полн=им,мн'},
#    {'lex': 'данный', 'gr': 'A,полн=вин,мн,неод'}],
#   'text': 'данные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'gr': 'PR='},
#    {'lex': 'в', 'gr': 'S,сокр=пр,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=пр,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=вин,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=вин,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=дат,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=дат,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=род,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=род,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=твор,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=твор,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=им,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=им,ед'}],
#   'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'различный', 'gr': 'A=пр,мн,полн'},
#    {'lex': 'различный', 'gr': 'A=вин,мн,полн,од'},
#    {'lex': 'различный', 'gr': 'A=род,мн,полн'}],
#   'text': 'различных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'форма', 'gr': 'S,жен,неод=пр,мн'}], 'text': 'формах'},
#  {'text': ': «'},
#  {'analysis': [{'lex': 'инфракрасный', 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'инфракрасная'},
#  {'text': '» — '},
#  {'analysis': [{'lex': 'где', 'gr': 'ADVPRO='}], 'text': 'где'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'чем', 'gr': 'CONJ='},
#    {'lex': 'что', 'gr': 'SPRO,ед,сред,неод=пр'},
#    {'lex': 'что', 'gr': 'SPRO,ед,сред,неод=твор'}],
#   'text': 'чем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активно', 'gr': 'ADV=срав'},
#    {'lex': 'активный', 'gr': 'A=срав'}],
#   'text': 'активнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'область', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'область', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'область'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'то', 'gr': 'SPRO,ед,сред,неод=твор'},
#    {'lex': 'тот', 'gr': 'APRO=дат,мн'},
#    {'lex': 'тот', 'gr': 'APRO=твор,ед,муж'},
#    {'lex': 'тот', 'gr': 'APRO=твор,ед,сред'},
#    {'lex': 'тем', 'gr': 'CONJ='},
#    {'lex': 'тема', 'gr': 'S,жен,неод=род,мн'},
#    {'lex': 'тема', 'gr': 'S,имя,муж,од=вин,мн'},
#    {'lex': 'тема', 'gr': 'S,имя,муж,од=род,мн'}],
#   'text': 'тем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=им'}], 'text': 'она'},
#  {'text': ' «'},
#  {'analysis': [{'lex': 'теплый', 'gr': 'A=срав'},
#    {'lex': 'тепло', 'gr': 'ADV=срав'}],
#   'text': 'теплее'},
#  {'text': '», '},
#  {'analysis': [{'lex': 'салют', 'gr': 'S,муж,неод=вин,мн'},
#    {'lex': 'салют', 'gr': 'S,муж,неод=им,мн'}],
#   'text': 'салюты'},
#  {'text': ' ('},
#  {'analysis': [{'lex': 'чем', 'gr': 'CONJ='},
#    {'lex': 'что', 'gr': 'SPRO,ед,сред,неод=пр'},
#    {'lex': 'что', 'gr': 'SPRO,ед,сред,неод=твор'}],
#   'text': 'чем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активно', 'gr': 'ADV=срав'},
#    {'lex': 'активный', 'gr': 'A=срав'}],
#   'text': 'активнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'область', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'область', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'область'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'то', 'gr': 'SPRO,ед,сред,неод=твор'},
#    {'lex': 'тот', 'gr': 'APRO=дат,мн'},
#    {'lex': 'тот', 'gr': 'APRO=твор,ед,муж'},
#    {'lex': 'тот', 'gr': 'APRO=твор,ед,сред'},
#    {'lex': 'тем', 'gr': 'CONJ='},
#    {'lex': 'тема', 'gr': 'S,жен,неод=род,мн'},
#    {'lex': 'тема', 'gr': 'S,имя,муж,од=вин,мн'},
#    {'lex': 'тема', 'gr': 'S,имя,муж,од=род,мн'}],
#   'text': 'тем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'больше', 'gr': 'ADV='},
#    {'lex': 'большой', 'gr': 'A=срав'},
#    {'lex': 'много', 'gr': 'ADV=срав'},
#    {'lex': 'больший', 'gr': 'A=ед,кр,сред'}],
#   'text': 'больше'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=пр,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=вин,мн'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=дат,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=род,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=им,мн'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=пр,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=вин,мн'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=дат,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=род,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=им,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,мн,неод=вин'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,мн,неод=им'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=пр,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=пр,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=вин,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=вин,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=дат,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=дат,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=род,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=род,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=твор,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=твор,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=им,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,имя,жен,од=им,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=пр,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=пр,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=вин,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=вин,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=дат,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=дат,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=род,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=род,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=твор,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=твор,ед'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=им,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,муж,од=им,ед'},
#    {'lex': 'конфетя', 'qual': 'bastard', 'gr': 'S,жен,од=род,ед'},
#    {'lex': 'конфетя', 'qual': 'bastard', 'gr': 'S,жен,од=им,мн'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,гео,ед,жен,неод=пр'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,гео,ед,жен,неод=дат'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,гео,ед,жен,неод=род'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,од=пр,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,од=дат,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,од=род,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,од=им,мн'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,гео,ед,муж,неод=пр'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,гео,ед,муж,неод=вин'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,гео,ед,муж,неод=дат'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,гео,ед,муж,неод=род'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,гео,ед,муж,неод=твор'},
#    {'lex': 'конфети', 'qual': 'bastard', 'gr': 'S,гео,ед,муж,неод=им'},
#    {'lex': 'конфетя', 'qual': 'bastard', 'gr': 'S,имя,жен,од=род,ед'},
#    {'lex': 'конфетя', 'qual': 'bastard', 'gr': 'S,имя,жен,од=им,мн'},
#    {'lex': 'конфетя', 'qual': 'bastard', 'gr': 'S,имя,муж,од=род,ед'},
#    {'lex': 'конфетя', 'qual': 'bastard', 'gr': 'S,имя,муж,од=им,мн'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,ед,жен,неод=пр'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,ед,жен,неод=дат'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,ед,жен,неод=род'}],
#   'text': 'конфети'},
#  {'text': '), '},
#  {'analysis': [{'lex': 'простой', 'gr': 'A=вин,ед,полн,муж,неод'},
#    {'lex': 'простой', 'gr': 'A=им,ед,полн,муж'},
#    {'lex': 'простой', 'gr': 'A=пр,ед,полн,жен'},
#    {'lex': 'простой', 'gr': 'A=дат,ед,полн,жен'},
#    {'lex': 'простой', 'gr': 'A=род,ед,полн,жен'},
#    {'lex': 'простой', 'gr': 'A=твор,ед,полн,жен'},
#    {'lex': 'простой', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'простой', 'gr': 'S,муж,неод=им,ед'},
#    {'lex': 'простаивать', 'gr': 'V,нп=ед,пов,2-л,сов'}],
#   'text': 'простой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'список', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'список', 'gr': 'S,муж,неод=им,ед'}],
#   'text': 'список'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'с', 'gr': 'PR='},
#    {'lex': 'с', 'gr': 'S,сокр=пр,мн'},
#    {'lex': 'с', 'gr': 'S,сокр=пр,ед'},
#    {'lex': 'с', 'gr': 'S,сокр=вин,мн'},
#    {'lex': 'с', 'gr': 'S,сокр=вин,ед'},
#    {'lex': 'с', 'gr': 'S,сокр=дат,мн'},
#    {'lex': 'с', 'gr': 'S,сокр=дат,ед'},
#    {'lex': 'с', 'gr': 'S,сокр=род,мн'},
#    {'lex': 'с', 'gr': 'S,сокр=род,ед'},
#    {'lex': 'с', 'gr': 'S,сокр=твор,мн'},
#    {'lex': 'с', 'gr': 'S,сокр=твор,ед'},
#    {'lex': 'с', 'gr': 'S,сокр=им,мн'},
#    {'lex': 'с', 'gr': 'S,сокр=им,ед'}],
#   'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сортировка', 'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'сортировкой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'по', 'gr': 'PR='}], 'text': 'по'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активность', 'gr': 'S,жен,неод=пр,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=вин,мн'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=дат,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=род,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=им,мн'}],
#   'text': 'активности'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'колба', 'gr': 'S,жен,неод=вин,мн'},
#    {'lex': 'колба', 'gr': 'S,жен,неод=род,ед'},
#    {'lex': 'колба', 'gr': 'S,жен,неод=им,мн'}],
#   'text': 'колбы'},
#  {'text': ' ('},
#  {'analysis': [{'lex': 'чем', 'gr': 'CONJ='},
#    {'lex': 'что', 'gr': 'SPRO,ед,сред,неод=пр'},
#    {'lex': 'что', 'gr': 'SPRO,ед,сред,неод=твор'}],
#   'text': 'чем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'заполненный', 'qual': 'bastard', 'gr': 'A=срав'}],
#   'text': 'заполненнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'колба', 'gr': 'S,жен,неод=им,ед'}], 'text': 'колба'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'то', 'gr': 'SPRO,ед,сред,неод=твор'},
#    {'lex': 'тот', 'gr': 'APRO=дат,мн'},
#    {'lex': 'тот', 'gr': 'APRO=твор,ед,муж'},
#    {'lex': 'тот', 'gr': 'APRO=твор,ед,сред'},
#    {'lex': 'тем', 'gr': 'CONJ='},
#    {'lex': 'тема', 'gr': 'S,жен,неод=род,мн'},
#    {'lex': 'тема', 'gr': 'S,имя,муж,од=вин,мн'},
#    {'lex': 'тема', 'gr': 'S,имя,муж,од=род,мн'}],
#   'text': 'тем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активно', 'gr': 'ADV=срав'},
#    {'lex': 'активный', 'gr': 'A=срав'}],
#   'text': 'активнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'область', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'область', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'область'},
#  {'text': '), '},
#  {'analysis': [{'lex': 'облако', 'gr': 'S,сред,неод=вин,мн'},
#    {'lex': 'облако', 'gr': 'S,сред,неод=род,ед'},
#    {'lex': 'облако', 'gr': 'S,сред,неод=им,мн'}],
#   'text': 'облака'},
#  {'text': ' ('},
#  {'analysis': [{'lex': 'на', 'gr': 'PR='}, {'lex': 'на', 'gr': 'PART='}],
#   'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мой', 'gr': 'APRO=вин,ед,муж,неод'},
#    {'lex': 'мой', 'gr': 'APRO=им,ед,муж'},
#    {'lex': 'мыть', 'gr': 'V,несов,пе=ед,пов,2-л'}],
#   'text': 'мой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взгляд', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'взгляд', 'gr': 'S,муж,неод=им,ед'}],
#   'text': 'взгляд'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'наиболее', 'gr': 'ADV='}], 'text': 'наиболее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'удобный', 'gr': 'A=вин,ед,полн,муж,неод'},
#    {'lex': 'удобный', 'gr': 'A=им,ед,полн,муж'}],
#   'text': 'удобный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вариант', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'вариант', 'gr': 'S,муж,неод=им,ед'},
#    {'lex': 'варианта', 'gr': 'S,редк,жен,неод=род,мн'}],
#   'text': 'вариант'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'совмещать', 'gr': 'V=непрош,ед,изъяв,3-л,несов,пе'}],
#   'text': 'совмещает'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'gr': 'PR='},
#    {'lex': 'в', 'gr': 'S,сокр=пр,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=пр,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=вин,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=вин,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=дат,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=дат,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=род,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=род,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=твор,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=твор,ед'},
#    {'lex': 'в', 'gr': 'S,сокр=им,мн'},
#    {'lex': 'в', 'gr': 'S,сокр=им,ед'}],
#   'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'себя', 'gr': 'SPRO=пр'},
#    {'lex': 'себя', 'gr': 'SPRO=дат'},
#    {'lex': 'себе', 'gr': 'PART='},
#    {'lex': 'себ', 'gr': 'S,имя,муж,од=пр,ед'}],
#   'text': 'себе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'весь', 'gr': 'APRO=им,мн'},
#    {'lex': 'весь', 'gr': 'APRO=вин,ед,сред'},
#    {'lex': 'весь', 'gr': 'APRO=им,ед,сред'},
#    {'lex': 'весь', 'gr': 'APRO=вин,мн,неод'},
#    {'lex': 'все', 'gr': 'ADV='},
#    {'lex': 'все', 'gr': 'SPRO,мн=вин'},
#    {'lex': 'все', 'gr': 'SPRO,мн=им'},
#    {'lex': 'все', 'gr': 'PART='},
#    {'lex': 'все', 'gr': 'SPRO,ед,сред,неод=вин'},
#    {'lex': 'все', 'gr': 'SPRO,ед,сред,неод=им'}],
#   'text': 'все'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'остальной', 'gr': 'APRO=им,мн'},
#    {'lex': 'остальной', 'gr': 'APRO=вин,мн,неод'},
#    {'lex': 'остальное', 'gr': 'S,сред,неод=вин,мн'},
#    {'lex': 'остальное', 'gr': 'S,сред,неод=им,мн'},
#    {'lex': 'остальной', 'gr': 'A,полн=им,мн'},
#    {'lex': 'остальной', 'gr': 'A,полн=вин,мн,неод'}],
#   'text': 'остальные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вместе', 'gr': 'ADV='}], 'text': 'вместе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взять',
#     'gr': 'V,сов,пе=прош,вин,мн,прич,полн,страд,неод'},
#    {'lex': 'взять', 'gr': 'V,сов,пе=прош,им,мн,прич,полн,страд'}],
#   'text': 'взятые'},
#  {'text': '. '},
#  {'text': '\\s'},
#  {'analysis': [{'lex': 'для', 'gr': 'PR='}], 'text': 'Для'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'кто', 'gr': 'SPRO,ед,муж,од=вин'},
#    {'lex': 'кто', 'gr': 'SPRO,ед,муж,од=род'}],
#   'text': 'кого'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'это', 'gr': 'SPRO,ед,сред,неод=вин'},
#    {'lex': 'это', 'gr': 'SPRO,ед,сред,неод=им'},
#    {'lex': 'это', 'gr': 'PART='},
#    {'lex': 'этот', 'gr': 'APRO=вин,ед,сред'},
#    {'lex': 'этот', 'gr': 'APRO=им,ед,сред'}],
#   'text': 'это'},
#  {'text': '?'},
#  {'text': '\n'}]

# %% [markdown]
# ## **Разбор с дисамбигуацией**

# %%
# !./mystem -d -isc --format json text.txt text_parsed_disamb.txt

import json
d = [json.loads(line) for line in open('text_parsed_disamb.txt')]
d[3]
# Out:
# [{'analysis': [{'lex': 'сервис', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'сервис', 'gr': 'S,муж,неод=им,ед'}],
#   'text': 'Сервис'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'позволять', 'gr': 'V,пе=непрош,ед,изъяв,3-л,несов'}],
#   'text': 'позволяет'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'отслеживать', 'gr': 'V=инф,несов,пе'}],
#   'text': 'отслеживать'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активность', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'активность'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'определенный', 'gr': 'A=пр,мн,полн'},
#    {'lex': 'определенный', 'gr': 'A=вин,мн,полн,од'},
#    {'lex': 'определенный', 'gr': 'A=род,мн,полн'}],
#   'text': 'определенных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пользователь', 'gr': 'S,муж,од=вин,мн'},
#    {'lex': 'пользователь', 'gr': 'S,муж,од=род,мн'}],
#   'text': 'пользователей'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'и', 'gr': 'CONJ='}], 'text': 'и'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'выводить', 'gr': 'V=инф,несов,пе'}],
#   'text': 'выводить'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'этот', 'gr': 'APRO=им,мн'},
#    {'lex': 'этот', 'gr': 'APRO=вин,мн,неод'}],
#   'text': 'эти'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'данные', 'gr': 'S,мн,неод=вин'},
#    {'lex': 'данные', 'gr': 'S,мн,неод=им'}],
#   'text': 'данные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'различный', 'gr': 'A=пр,мн,полн'},
#    {'lex': 'различный', 'gr': 'A=вин,мн,полн,од'},
#    {'lex': 'различный', 'gr': 'A=род,мн,полн'}],
#   'text': 'различных'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'форма', 'gr': 'S,жен,неод=пр,мн'}], 'text': 'формах'},
#  {'text': ': «'},
#  {'analysis': [{'lex': 'инфракрасный', 'gr': 'A=им,ед,полн,жен'}],
#   'text': 'инфракрасная'},
#  {'text': '» — '},
#  {'analysis': [{'lex': 'где', 'gr': 'ADVPRO='}], 'text': 'где'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'чем', 'gr': 'CONJ='}], 'text': 'чем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активно', 'gr': 'ADV=срав'}], 'text': 'активнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'область', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'область', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'область'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'тем', 'gr': 'CONJ='}], 'text': 'тем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'она', 'gr': 'SPRO,ед,3-л,жен=им'}], 'text': 'она'},
#  {'text': ' «'},
#  {'analysis': [{'lex': 'тепло', 'gr': 'ADV=срав'}], 'text': 'теплее'},
#  {'text': '», '},
#  {'analysis': [{'lex': 'салют', 'gr': 'S,муж,неод=вин,мн'},
#    {'lex': 'салют', 'gr': 'S,муж,неод=им,мн'}],
#   'text': 'салюты'},
#  {'text': ' ('},
#  {'analysis': [{'lex': 'чем', 'gr': 'CONJ='}], 'text': 'чем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активно', 'gr': 'ADV=срав'}], 'text': 'активнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'область', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'область', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'область'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'тем', 'gr': 'CONJ='}], 'text': 'тем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'много', 'gr': 'ADV=срав'}], 'text': 'больше'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=пр,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=вин,мн'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=дат,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=род,ед'},
#    {'lex': 'конфеть', 'qual': 'bastard', 'gr': 'S,жен,неод=им,мн'}],
#   'text': 'конфети'},
#  {'text': '), '},
#  {'analysis': [{'lex': 'простой', 'gr': 'A=вин,ед,полн,муж,неод'},
#    {'lex': 'простой', 'gr': 'A=им,ед,полн,муж'},
#    {'lex': 'простой', 'gr': 'A=пр,ед,полн,жен'},
#    {'lex': 'простой', 'gr': 'A=дат,ед,полн,жен'},
#    {'lex': 'простой', 'gr': 'A=род,ед,полн,жен'},
#    {'lex': 'простой', 'gr': 'A=твор,ед,полн,жен'}],
#   'text': 'простой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'список', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'список', 'gr': 'S,муж,неод=им,ед'}],
#   'text': 'список'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'с', 'gr': 'PR='}], 'text': 'с'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'сортировка', 'gr': 'S,жен,неод=твор,ед'}],
#   'text': 'сортировкой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'по', 'gr': 'PR='}], 'text': 'по'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активность', 'gr': 'S,жен,неод=пр,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=вин,мн'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=дат,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=род,ед'},
#    {'lex': 'активность', 'gr': 'S,жен,неод=им,мн'}],
#   'text': 'активности'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'колба', 'gr': 'S,жен,неод=вин,мн'},
#    {'lex': 'колба', 'gr': 'S,жен,неод=род,ед'},
#    {'lex': 'колба', 'gr': 'S,жен,неод=им,мн'}],
#   'text': 'колбы'},
#  {'text': ' ('},
#  {'analysis': [{'lex': 'чем', 'gr': 'CONJ='}], 'text': 'чем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'заполненный', 'qual': 'bastard', 'gr': 'A=срав'}],
#   'text': 'заполненнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'колба', 'gr': 'S,жен,неод=им,ед'}], 'text': 'колба'},
#  {'text': ', '},
#  {'analysis': [{'lex': 'тем', 'gr': 'CONJ='}], 'text': 'тем'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'активно', 'gr': 'ADV=срав'}], 'text': 'активнее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'область', 'gr': 'S,жен,неод=вин,ед'},
#    {'lex': 'область', 'gr': 'S,жен,неод=им,ед'}],
#   'text': 'область'},
#  {'text': '), '},
#  {'analysis': [{'lex': 'облако', 'gr': 'S,сред,неод=вин,мн'},
#    {'lex': 'облако', 'gr': 'S,сред,неод=род,ед'},
#    {'lex': 'облако', 'gr': 'S,сред,неод=им,мн'}],
#   'text': 'облака'},
#  {'text': ' ('},
#  {'analysis': [{'lex': 'на', 'gr': 'PR='}], 'text': 'на'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'мой', 'gr': 'APRO=вин,ед,муж,неод'},
#    {'lex': 'мой', 'gr': 'APRO=им,ед,муж'}],
#   'text': 'мой'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взгляд', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'взгляд', 'gr': 'S,муж,неод=им,ед'}],
#   'text': 'взгляд'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'наиболее', 'gr': 'ADV='}], 'text': 'наиболее'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'удобный', 'gr': 'A=вин,ед,полн,муж,неод'},
#    {'lex': 'удобный', 'gr': 'A=им,ед,полн,муж'}],
#   'text': 'удобный'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вариант', 'gr': 'S,муж,неод=вин,ед'},
#    {'lex': 'вариант', 'gr': 'S,муж,неод=им,ед'}],
#   'text': 'вариант'},
#  {'text': ' — '},
#  {'analysis': [{'lex': 'совмещать', 'gr': 'V=непрош,ед,изъяв,3-л,несов,пе'}],
#   'text': 'совмещает'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'в', 'gr': 'PR='}], 'text': 'в'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'себя', 'gr': 'SPRO=пр'},
#    {'lex': 'себя', 'gr': 'SPRO=дат'}],
#   'text': 'себе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'весь', 'gr': 'APRO=им,мн'},
#    {'lex': 'весь', 'gr': 'APRO=вин,ед,сред'},
#    {'lex': 'весь', 'gr': 'APRO=им,ед,сред'},
#    {'lex': 'весь', 'gr': 'APRO=вин,мн,неод'}],
#   'text': 'все'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'остальной', 'gr': 'APRO=им,мн'},
#    {'lex': 'остальной', 'gr': 'APRO=вин,мн,неод'}],
#   'text': 'остальные'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'вместе', 'gr': 'ADV='}], 'text': 'вместе'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'взять',
#     'gr': 'V,сов,пе=прош,вин,мн,прич,полн,страд,неод'},
#    {'lex': 'взять', 'gr': 'V,сов,пе=прош,им,мн,прич,полн,страд'}],
#   'text': 'взятые'},
#  {'text': '. '},
#  {'text': '\\s'},
#  {'analysis': [{'lex': 'для', 'gr': 'PR='}], 'text': 'Для'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'кто', 'gr': 'SPRO,ед,муж,од=вин'},
#    {'lex': 'кто', 'gr': 'SPRO,ед,муж,од=род'}],
#   'text': 'кого'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'это', 'gr': 'SPRO,ед,сред,неод=вин'},
#    {'lex': 'это', 'gr': 'SPRO,ед,сред,неод=им'}],
#   'text': 'это'},
#  {'text': '?'},
#  {'text': '\n'}]

# %% [markdown]
# ## __Комментарий__
#
# Конечно, между двумя методами анализа есть различия.
# С дизамбигуцаией Mystem точнее выводит значение слова (или дает меньше возможных вариантов).
#
#
# Например, **без дизамбигуации** для существительного _данные_ вывелось 6 вариантов разбора (2 существительных, 2 глагола и 2 прилагательных).
#
# **С дизамбигуацией** мы получили только один верный вариант разбора (сущеситвительное мн.ч. в винительном падеже).
