# %% [markdown]
# # Домашнее задание  № 5. Матричные разложения/Тематическое моделирование

# %% [markdown]
# ### Задание № 1 (4 балла)

# %% [markdown]
# Попробуйте матричные разложения с 5 классификаторами - SGDClassifier, KNeighborsClassifier, MultinomialNB, RandomForest, ExtraTreesClassifier (про него подробнее почитайте в документации, он похож на RF). Используйте и NMF и SVD. Сравните результаты на кросс-валидации и выберите лучшее сочетание.
#
# В итоге у вас должно получиться, как минимум 10 моделей (два разложения на каждый классификатор). Используйте 1 и те же параметры кросс-валидации. Параметры векторизации, параметры K в матричных разложениях, параметры классификаторов могут быть разными между экспериментами.

# %% [markdown]
# Можете взять поменьше данных, если все будет обучаться слишком долго (не ставьте параметр K слишком большим в NMF, иначе точно будет слишком долго)

# %%
import gensim
import pandas as pd
import numpy as np
from pymorphy2 import MorphAnalyzer
import pyLDAvis.gensim_models
from collections import Counter
from string import punctuation
from razdel import tokenize as razdel_tokenize
from sklearn.decomposition import TruncatedSVD, NMF, PCA, LatentDirichletAllocation
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics.pairwise import cosine_distances
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, StratifiedKFold
import warnings
from matplotlib import pyplot as plt
import seaborn as sns
morph = MorphAnalyzer()
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('avito_category_classification.csv')

# %%
data
# Out:
#                    category_name  \
# 0                     Автомобили
# 1         Детская одежда и обувь
# 2              Предложение услуг
# 3                     Автомобили
# 4                Бытовая техника
# ...                          ...
# 9893  Товары для детей и игрушки
# 9894      Детская одежда и обувь
# 9895   Одежда, обувь, аксессуары
# 9896      Детская одежда и обувь
# 9897             Бытовая техника
#
#                                             description
# 0               отличное состояние,обслужиание в салоне
# 1     В отличном состоянии. Фирма KIKO. Очень теплый...
# 2     Изготовление ограждений, перил,качелей, турник...
# 3     Автомобиль в отличном техническом состоянии. О...
# 4     Продается газовая плита "Гефест" (Белоруссия) ...
# ...                                                 ...
# 9893  Чтобы посмотреть весь ассортимент нашего магаз...
# 9894  Весна,осень.74-80.вопросы можно в вайбер,двухс...
# 9895  Кимоно Green Hill. Состояние  отличное,  рост ...
# 9896  Б/у кроссовки на девочку. Носили только в спор...
# 9897                            Холодильник на гарантии
#
# [9898 rows x 2 columns]

# %%
# добавим лемматизацию
def normalize(text):
    normalized_text = [word.text.strip(punctuation) for word \
                                                            in razdel_tokenize(text)]
    normalized_text = [word.lower() for word in normalized_text if word and len(word) < 20 ]
    normalized_text = [morph.parse(word)[0].normal_form for word in normalized_text]
    return ' '.join(normalized_text)

# %%
data['description_norm'] = data['description'].apply(normalize)

# %%
vectorizer = CountVectorizer(min_df=5, max_df=0.5)

# %%
def eval_table(X, y, pipeline, N=6):
    # зафиксируем порядок классов
    labels = list(set(y))
    
    # метрики отдельных фолдов будет хранить в табличке
    fold_metrics = pd.DataFrame(index=labels)
    # дополнительно также соберем таблицу ошибок
    errors = np.zeros((len(labels), len(labels)))
    
    # создаем стратегию кросс-валидации
    # shuffle=True (перемешивание) - часто критично важно указать
    # т.к. данные могут быть упорядочены и модель на этом обучится
    kfold = StratifiedKFold(n_splits=N, shuffle=True, )
    
    for i, (train_index, test_index) in enumerate(kfold.split(X, y)):
        # fit-predict как и раньше, но сразу пайплайном
        pipeline.fit(X[train_index], y[train_index])
        preds = pipeline.predict(X[test_index])
        
        # записываем метрику и индекс фолда
        fold_metrics[f'precision_{i}'] = precision_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'recall_{i}'] = recall_score(y[test_index], preds, labels=labels, average=None)
        fold_metrics[f'f1_{i}'] = f1_score(y[test_index], preds, labels=labels, average=None)
        errors += confusion_matrix(y[test_index], preds, labels=labels, normalize='true')
    
    # таблица для усредненных значений
    # тут мы берем колонки со значениями и усредняем их
    # часто также все метрики сразу суммируют и в конце просто делят на количество фолдов
    # но мы тут помимо среднего также хотим посмотреть на стандартное отклонение
    # чтобы понять как сильно варьируются оценки моделей
    result = pd.DataFrame(index=labels)
    result['precision'] = fold_metrics[[f'precision_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['precision_std'] = fold_metrics[[f'precision_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['recall'] = fold_metrics[[f'recall_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['recall_std'] = fold_metrics[[f'recall_{i}' for i in range(N)]].std(axis=1).round(2)
    
    result['f1'] = fold_metrics[[f'f1_{i}' for i in range(N)]].mean(axis=1).round(2)
    result['f1_std'] = fold_metrics[[f'f1_{i}' for i in range(N)]].std(axis=1).round(2)
    
    # добавим одну колонку со средним по всем классам
    result.loc['mean'] = result.mean().round(2)
    # проценты ошибок просто усредняем
    errors /= N
    
    return result, errors

# %% [markdown]
# ### SGDClassifier

# %%
pipeline_nmf = Pipeline([
    ('bow', vectorizer),
    ('decomposition', NMF(50)),
    ('scaler', StandardScaler()),
    ('clf', SGDClassifier())
])

# %%
metrics_nmf_sgd, errors_nmf_sgd = eval_table(data['description_norm'], data['category_name'], pipeline_nmf)
metrics_nmf_sgd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.78           0.03    0.77        0.07
# Квартиры                         0.95           0.02    0.93        0.02
# Товары для детей и игрушки       0.58           0.06    0.51        0.04
# Детская одежда и обувь           0.51           0.02    0.59        0.08
# Бытовая техника                  0.30           0.13    0.12        0.08
# Мебель и интерьер                0.39           0.14    0.26        0.04
# Одежда, обувь, аксессуары        0.57           0.03    0.61        0.06
# Ремонт и строительство           0.41           0.15    0.31        0.11
# Предложение услуг                0.60           0.17    0.59        0.07
# Телефоны                         0.71           0.09    0.66        0.08
# mean                             0.58           0.08    0.53        0.06
#
#                               f1  f1_std
# Автомобили                  0.78    0.05
# Квартиры                    0.94    0.00
# Товары для детей и игрушки  0.54    0.04
# Детская одежда и обувь      0.55    0.03
# Бытовая техника             0.16    0.06
# Мебель и интерьер           0.30    0.03
# Одежда, обувь, аксессуары   0.59    0.02
# Ремонт и строительство      0.35    0.12
# Предложение услуг           0.58    0.07
# Телефоны                    0.68    0.06
# mean                        0.55    0.05

# %%
pipeline_svd = Pipeline([
    ('bow', vectorizer),
    ('svd', TruncatedSVD(500)),
    ('scaler', StandardScaler()),
    ('clf', SGDClassifier())
])

# %%
metrics_svd_sgd, errors_svd_sgd = eval_table(data['description_norm'], data['category_name'], pipeline_svd)
metrics_svd_sgd
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.87           0.03    0.77        0.03
# Квартиры                         0.97           0.01    0.82        0.05
# Товары для детей и игрушки       0.64           0.05    0.63        0.03
# Детская одежда и обувь           0.68           0.04    0.79        0.02
# Бытовая техника                  0.57           0.09    0.39        0.07
# Мебель и интерьер                0.68           0.02    0.59        0.06
# Одежда, обувь, аксессуары        0.68           0.02    0.76        0.03
# Ремонт и строительство           0.54           0.05    0.49        0.04
# Предложение услуг                0.78           0.02    0.65        0.06
# Телефоны                         0.81           0.05    0.68        0.06
# mean                             0.72           0.04    0.66        0.04
#
#                               f1  f1_std
# Автомобили                  0.82    0.02
# Квартиры                    0.89    0.03
# Товары для детей и игрушки  0.64    0.03
# Детская одежда и обувь      0.73    0.02
# Бытовая техника             0.46    0.08
# Мебель и интерьер           0.63    0.04
# Одежда, обувь, аксессуары   0.72    0.01
# Ремонт и строительство      0.52    0.04
# Предложение услуг           0.71    0.03
# Телефоны                    0.74    0.05
# mean                        0.69    0.04

# %% [markdown]
# ### KNeighborsClassifier

# %%
pipeline_nmf = Pipeline([
    ('bow', vectorizer),
    ('decomposition', NMF(50)),
    ('clf', KNeighborsClassifier(n_neighbors=3))
])

metrics_nmf_knn, errors_nmf_knn = eval_table(data['description_norm'], data['category_name'], pipeline_nmf)
metrics_nmf_knn
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.45           0.06    0.69        0.05
# Квартиры                         0.89           0.04    0.83        0.04
# Товары для детей и игрушки       0.59           0.07    0.29        0.03
# Детская одежда и обувь           0.45           0.02    0.58        0.04
# Бытовая техника                  0.16           0.02    0.26        0.03
# Мебель и интерьер                0.23           0.04    0.22        0.05
# Одежда, обувь, аксессуары        0.53           0.01    0.52        0.01
# Ремонт и строительство           0.44           0.06    0.19        0.03
# Предложение услуг                0.60           0.05    0.50        0.06
# Телефоны                         0.69           0.09    0.37        0.08
# mean                             0.50           0.05    0.44        0.04
#
#                               f1  f1_std
# Автомобили                  0.55    0.06
# Квартиры                    0.86    0.03
# Товары для детей и игрушки  0.39    0.03
# Детская одежда и обувь      0.50    0.03
# Бытовая техника             0.20    0.02
# Мебель и интерьер           0.22    0.04
# Одежда, обувь, аксессуары   0.52    0.01
# Ремонт и строительство      0.26    0.04
# Предложение услуг           0.54    0.05
# Телефоны                    0.48    0.08
# mean                        0.45    0.04

# %%
pipeline_svd = Pipeline([
    ('bow', vectorizer),
    ('svd', TruncatedSVD(500)),
    ('clf', KNeighborsClassifier(n_neighbors=3))
])

metrics_svd_knn, errors_svd_knn = eval_table(data['description_norm'], data['category_name'], pipeline_svd)
metrics_svd_knn
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.47           0.06    0.71        0.07
# Квартиры                         0.88           0.04    0.77        0.04
# Товары для детей и игрушки       0.61           0.05    0.29        0.02
# Детская одежда и обувь           0.48           0.01    0.67        0.02
# Бытовая техника                  0.19           0.04    0.34        0.04
# Мебель и интерьер                0.36           0.05    0.29        0.04
# Одежда, обувь, аксессуары        0.54           0.04    0.53        0.03
# Ремонт и строительство           0.43           0.08    0.20        0.03
# Предложение услуг                0.73           0.05    0.48        0.06
# Телефоны                         0.78           0.06    0.35        0.06
# mean                             0.55           0.05    0.46        0.04
#
#                               f1  f1_std
# Автомобили                  0.56    0.04
# Квартиры                    0.82    0.03
# Товары для детей и игрушки  0.39    0.02
# Детская одежда и обувь      0.56    0.01
# Бытовая техника             0.25    0.04
# Мебель и интерьер           0.32    0.03
# Одежда, обувь, аксессуары   0.54    0.03
# Ремонт и строительство      0.27    0.04
# Предложение услуг           0.58    0.05
# Телефоны                    0.48    0.07
# mean                        0.48    0.04

# %% [markdown]
# ### RandomForest

# %%
pipeline_nmf = Pipeline([
    ('bow', vectorizer),
    ('decomposition', NMF(50)),
    ('clf', RandomForestClassifier(n_estimators=100, max_depth=1))
])

metrics_nmf_rf, errors_nmf_rf = eval_table(data['description_norm'], data['category_name'], pipeline_nmf)
metrics_nmf_rf
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.00           0.00    0.00        0.00
# Квартиры                         0.91           0.02    0.67        0.12
# Товары для детей и игрушки       0.00           0.00    0.00        0.00
# Детская одежда и обувь           0.46           0.07    0.55        0.07
# Бытовая техника                  0.00           0.00    0.00        0.00
# Мебель и интерьер                0.00           0.00    0.00        0.00
# Одежда, обувь, аксессуары        0.26           0.03    0.67        0.05
# Ремонт и строительство           0.00           0.00    0.00        0.00
# Предложение услуг                0.00           0.00    0.00        0.00
# Телефоны                         0.00           0.00    0.00        0.00
# mean                             0.16           0.01    0.19        0.02
#
#                               f1  f1_std
# Автомобили                  0.00    0.00
# Квартиры                    0.77    0.08
# Товары для детей и игрушки  0.00    0.00
# Детская одежда и обувь      0.50    0.04
# Бытовая техника             0.00    0.00
# Мебель и интерьер           0.00    0.00
# Одежда, обувь, аксессуары   0.38    0.03
# Ремонт и строительство      0.00    0.00
# Предложение услуг           0.00    0.00
# Телефоны                    0.00    0.00
# mean                        0.16    0.02

# %%
pipeline_svd = Pipeline([
    ('bow', vectorizer),
    ('svd', TruncatedSVD(500)),
    ('clf', RandomForestClassifier(n_estimators=100, max_depth=1))
])

metrics_svd_knn, errors_svd_knn = eval_table(data['description_norm'], data['category_name'], pipeline_svd)
metrics_svd_knn
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.00           0.00    0.00        0.00
# Квартиры                         0.00           0.00    0.00        0.00
# Товары для детей и игрушки       0.00           0.00    0.00        0.00
# Детская одежда и обувь           0.30           0.05    0.45        0.09
# Бытовая техника                  0.00           0.00    0.00        0.00
# Мебель и интерьер                0.00           0.00    0.00        0.00
# Одежда, обувь, аксессуары        0.33           0.01    0.83        0.05
# Ремонт и строительство           0.00           0.00    0.00        0.00
# Предложение услуг                0.00           0.00    0.00        0.00
# Телефоны                         0.00           0.00    0.00        0.00
# mean                             0.06           0.01    0.13        0.01
#
#                               f1  f1_std
# Автомобили                  0.00    0.00
# Квартиры                    0.00    0.00
# Товары для детей и игрушки  0.00    0.00
# Детская одежда и обувь      0.36    0.06
# Бытовая техника             0.00    0.00
# Мебель и интерьер           0.00    0.00
# Одежда, обувь, аксессуары   0.47    0.02
# Ремонт и строительство      0.00    0.00
# Предложение услуг           0.00    0.00
# Телефоны                    0.00    0.00
# mean                        0.08    0.01

# %% [markdown]
# ### ExtraTreesClassifier

# %%
pipeline_nmf = Pipeline([
    ('bow', vectorizer),
    ('decomposition', NMF(50)),
    ('clf', ExtraTreesClassifier(n_estimators=100, random_state=0))
])

metrics_nmf_extra_trees, errors_nmf_extra_trees = eval_table(data['description_norm'], data['category_name'], pipeline_nmf)
metrics_nmf_extra_trees
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.74           0.06    0.85        0.05
# Квартиры                         0.92           0.01    0.96        0.01
# Товары для детей и игрушки       0.68           0.03    0.52        0.04
# Детская одежда и обувь           0.61           0.01    0.71        0.02
# Бытовая техника                  0.55           0.06    0.20        0.04
# Мебель и интерьер                0.59           0.05    0.39        0.04
# Одежда, обувь, аксессуары        0.62           0.01    0.70        0.02
# Ремонт и строительство           0.57           0.08    0.35        0.03
# Предложение услуг                0.69           0.03    0.75        0.04
# Телефоны                         0.81           0.02    0.71        0.08
# mean                             0.68           0.04    0.61        0.04
#
#                               f1  f1_std
# Автомобили                  0.79    0.05
# Квартиры                    0.94    0.01
# Товары для детей и игрушки  0.59    0.03
# Детская одежда и обувь      0.65    0.01
# Бытовая техника             0.29    0.05
# Мебель и интерьер           0.47    0.04
# Одежда, обувь, аксессуары   0.66    0.01
# Ремонт и строительство      0.43    0.04
# Предложение услуг           0.72    0.03
# Телефоны                    0.75    0.05
# mean                        0.63    0.03

# %%
pipeline_svd = Pipeline([
    ('bow', vectorizer),
    ('svd', TruncatedSVD(500)),
    ('clf', ExtraTreesClassifier(n_estimators=100, random_state=0))
])

metrics_svd_extra_trees, errors_svd_extra_trees = eval_table(data['description_norm'], data['category_name'], pipeline_svd)
metrics_svd_extra_trees
# Out:
#                             precision  precision_std  recall  recall_std  \
# Автомобили                       0.81           0.04    0.46        0.05
# Квартиры                         0.73           0.04    0.82        0.03
# Товары для детей и игрушки       0.67           0.05    0.18        0.02
# Детская одежда и обувь           0.46           0.01    0.74        0.02
# Бытовая техника                  0.61           0.16    0.13        0.03
# Мебель и интерьер                0.78           0.05    0.16        0.03
# Одежда, обувь, аксессуары        0.47           0.01    0.73        0.02
# Ремонт и строительство           0.66           0.10    0.10        0.02
# Предложение услуг                0.87           0.08    0.27        0.05
# Телефоны                         0.88           0.04    0.37        0.04
# mean                             0.69           0.06    0.40        0.03
#
#                               f1  f1_std
# Автомобили                  0.59    0.05
# Квартиры                    0.77    0.03
# Товары для детей и игрушки  0.28    0.03
# Детская одежда и обувь      0.57    0.01
# Бытовая техника             0.21    0.05
# Мебель и интерьер           0.26    0.04
# Одежда, обувь, аксессуары   0.57    0.01
# Ремонт и строительство      0.17    0.03
# Предложение услуг           0.41    0.06
# Телефоны                    0.52    0.05
# mean                        0.43    0.04

# %% [markdown]
# **Лучший результат показала комбинация SVD и SGDClassifier: mean f1 score 0.68**

# %% [markdown]
# # Задание № 2 (6 баллов)

# %% [markdown]
# В Gensim тоже можно добавить нграммы и tfidf. Постройте 1 модель без них (как в семинаре) и еще 3 модели (1 с нграммами, 1 с tfidf и 1 с нграммами и с tfidf). Сранивте качество с помощью метрик (перплексия, когерентность) и на глаз. Определите лучшую модель. Для каждой модели выберите 1 самую красивую на ваш взгляд тему.
#
# Используйте данные википедии из семинара. Можете взять поменьше данных, если все обучается долго.
#
# Важное требование - получившиеся модели не должны быть совсем плохими. Если хороших тем не получается, попробуйте настроить гиперпараметры, отфильтровать словарь по-другому.

# %%
texts = open('wiki_data.txt').read().splitlines()[:1000]
texts = ([normalize(text) for text in texts])

# %% [markdown]
# ### Model 1 (No TFIDF, no ngramms)

# %%
dictionary1 = gensim.corpora.Dictionary((text.split() for text in texts))

dictionary1.filter_extremes(no_above=0.1, no_below=10)
dictionary1.compactify()

# %%
corpus = [dictionary1.doc2bow(text.split()) for text in texts]

# %%
lda = gensim.models.LdaMulticore(corpus, 
                                 100,
                                 alpha='asymmetric',
                                 id2word=dictionary1, 
                                 passes=10)

# %%
lda.print_topics()
# Out:
# [(99,
#   '0.035*"г" + 0.015*"метод" + 0.014*"университет" + 0.011*"профессор" + 0.010*"учёный" + 0.010*"научный" + 0.010*"институт" + 0.009*"элемент" + 0.009*"определение" + 0.008*"соединение"'),
#  (98,
#   '0.027*"ссср" + 0.023*"московский" + 0.018*"университет" + 0.017*"москва" + 0.016*"александр" + 0.016*"академия" + 0.015*"наука" + 0.014*"орден" + 0.013*"институт" + 0.012*"профессор"'),
#  (97,
#   '0.030*"пара" + 0.016*"трава" + 0.014*"член" + 0.014*"племя" + 0.012*"уже" + 0.012*"студент" + 0.010*"михаил" + 0.010*"век" + 0.010*"иногда" + 0.009*"ныне"'),
#  (96,
#   '0.040*"монастырь" + 0.025*"собор" + 0.023*"корпус" + 0.016*"западный" + 0.015*"библиотека" + 0.015*"корабль" + 0.015*"набор" + 0.013*"ii" + 0.013*"версия" + 0.012*"система"'),
#  (93,
#   '0.082*"пространство" + 0.081*"значение" + 0.044*"если" + 0.043*"набор" + 0.041*"образ" + 0.038*"есть" + 0.032*"точка" + 0.028*"индекс" + 0.021*"помощь" + 0.021*"обозначать"'),
#  (95,
#   '0.035*"тысяча" + 0.033*"орудие" + 0.025*"южный" + 0.016*"данные" + 0.016*"тыс" + 0.015*"перепись" + 0.014*"2015" + 0.011*"численность" + 0.011*"12" + 0.010*"г"'),
#  (94,
#   '0.080*"соревнование" + 0.074*"спортсмен" + 0.055*"атлетика" + 0.037*"лёгкий" + 0.033*"1996" + 0.028*"2000" + 0.028*"тяжёлый" + 0.017*"атланта" + 0.016*"институт" + 0.014*"австралия"'),
#  (91,
#   '0.034*"министр" + 0.026*"партия" + 0.022*"советский" + 0.021*"кабинет" + 0.020*"эсминец" + 0.015*"флот" + 0.015*"декабрь" + 0.014*"проект" + 0.014*"23" + 0.013*"правительство"'),
#  (92,
#   '0.074*"корабль" + 0.033*"космический" + 0.025*"миссия" + 0.020*"полёт" + 0.018*"церковь" + 0.014*"станция" + 0.011*"земля" + 0.010*"система" + 0.010*"использоваться" + 0.009*"экипаж"'),
#  (90,
#   '0.076*"экипаж" + 0.056*"финал" + 0.036*"дисциплина" + 0.035*"раунд" + 0.035*"сильный" + 0.030*"выходить" + 0.029*"бронзовый" + 0.029*"серебряный" + 0.029*"заезд" + 0.028*"канада"'),
#  (9,
#   '0.042*"сезон" + 0.026*"команда" + 0.019*"финал" + 0.019*"игрок" + 0.016*"серия" + 0.013*"играть" + 0.013*"счёт" + 0.012*"матч" + 0.012*"персонаж" + 0.011*"очко"'),
#  (8,
#   '0.046*"чемпионат" + 0.045*"ямайка" + 0.020*"футбол" + 0.019*"зимний" + 0.018*"список" + 0.017*"азербайджан" + 0.016*"объект" + 0.016*"заезд" + 0.014*"команда" + 0.014*"бронзовый"'),
#  (7,
#   '0.042*"1984" + 0.020*"i" + 0.019*"лос-анджелес" + 0.012*"1994" + 0.011*"президент" + 0.010*"участник" + 0.009*"ум" + 0.008*"норвегия" + 0.008*"умереть" + 0.008*"г"'),
#  (6,
#   '0.136*"департамент" + 0.051*"км²" + 0.046*"жужевать" + 0.045*"провинция" + 0.033*"аргентина" + 0.023*"плотность" + 0.023*"включать" + 0.022*"2010" + 0.022*"национальный" + 0.022*"граничить"'),
#  (5,
#   '0.013*"право" + 0.013*"компания" + 0.011*"клуб" + 0.010*"политический" + 0.010*"генеральный" + 0.009*"контроль" + 0.008*"система" + 0.008*"партия" + 0.007*"лига" + 0.007*"1992"'),
#  (4,
#   '0.038*"боливия" + 0.023*"1972" + 0.022*"николай" + 0.021*"н" + 0.021*"иванович" + 0.015*"1940" + 0.014*"март" + 0.013*"зимний" + 0.009*"исключить" + 0.009*"строй"'),
#  (3,
#   '0.023*"бой" + 0.022*"улица" + 0.013*"афины" + 0.013*"иван" + 0.013*"царь" + 0.013*"противник" + 0.013*"земля" + 0.012*"герой" + 0.012*"должный" + 0.012*"здесь"'),
#  (2,
#   '0.014*"армия" + 0.014*"б" + 0.013*"секретарь" + 0.013*"институт" + 0.012*"народный" + 0.012*"жизнь" + 0.011*"1937" + 0.010*"должность" + 0.010*"советский" + 0.010*"сопротивление"'),
#  (1,
#   '0.016*"фильм" + 0.011*"1956" + 0.008*"французский" + 0.008*"смерть" + 0.007*"франция" + 0.006*"качество" + 0.006*"февраль" + 0.006*"ребёнок" + 0.006*"жена" + 0.005*"18"'),
#  (0,
#   '0.028*"процесс" + 0.013*"карта" + 0.012*"лесной" + 0.011*"сторона" + 0.009*"1952" + 0.008*"провинция" + 0.007*"здесь" + 0.007*"рука" + 0.007*"легкоатлет" + 0.007*"уровень"')]

# %% [markdown]
# ### Model 2 (Ngramms)

# %% [markdown]
# Нграммы добавляются вот так (перед созданием словаря)

# %%
texts = [text.split() for text in texts]
ph = gensim.models.Phrases(texts, scoring='npmi', threshold=0.4) # threshold можно подбирать
p = gensim.models.phrases.Phraser(ph)
ngrammed_texts = p[texts] 



# ! не забудьте, что далее вам нужно будет использовать ngrammed_texts

# %%
dictionary2 = gensim.corpora.Dictionary((ngrammed_texts))

dictionary2.filter_extremes(no_above=0.1, no_below=10)
dictionary2.compactify()

corpus2 = [dictionary2.doc2bow(text) for text in ngrammed_texts]

# %%
lda_ngramms = gensim.models.LdaMulticore(corpus2, 
                                 100,
                                 alpha='asymmetric',
                                 id2word=dictionary2, 
                                 passes=10) 

lda_ngramms.print_topics()
# Out:
# [(99,
#   '0.045*"община" + 0.044*"канада" + 0.039*"река" + 0.023*"гора" + 0.020*"поселение" + 0.019*"км²" + 0.017*"граница" + 0.016*"площадь" + 0.016*"провинция" + 0.016*"индеец"'),
#  (98,
#   '0.028*"монастырь" + 0.027*"здание" + 0.024*"собор" + 0.020*"музей" + 0.014*"художник" + 0.011*"озеро" + 0.010*"башня" + 0.010*"построить" + 0.009*"святой" + 0.007*"фон"'),
#  (97,
#   '0.057*"посёлок" + 0.030*"плод" + 0.026*"на_расстояние" + 0.025*"харьковский_область" + 0.017*"население" + 0.017*"м_ж" + 0.016*"село" + 0.016*"по_перепись" + 0.015*"2001_год" + 0.013*"км"'),
#  (96,
#   '0.074*"станция" + 0.046*"хутор" + 0.036*"км" + 0.025*"сельский_поселение" + 0.025*"дубовский_район" + 0.024*"население" + 0.020*"комплекс" + 0.019*"север" + 0.017*"округ" + 0.015*"согласно"'),
#  (95,
#   '0.055*"департамент" + 0.045*"аргентина" + 0.030*"административный_центр" + 0.029*"км²" + 0.028*"состав_провинция" + 0.027*"национальный_институт" + 0.027*"статистика" + 0.027*"муниципалитет" + 0.027*"департамент_расположить" + 0.027*"что_составить"'),
#  (94,
#   '0.024*"доска" + 0.017*"1977" + 0.017*"компания" + 0.016*"канада" + 0.012*"должный" + 0.012*"1976" + 0.011*"сша" + 0.010*"бой" + 0.010*"1978" + 0.009*"вода"'),
#  (92,
#   '0.174*"остров" + 0.055*"метр" + 0.021*"назвать" + 0.020*"честь" + 0.017*"километр" + 0.017*"около" + 0.016*"земля" + 0.015*"лёд" + 0.015*"мыс" + 0.015*"остров_архипелаг"'),
#  (93,
#   '0.061*"процесс" + 0.031*"сторона" + 0.023*"киргизия" + 0.020*"рука" + 0.019*"функция" + 0.019*"параметр" + 0.016*"голова" + 0.016*"выход" + 0.015*"вследствие" + 0.013*"граница"'),
#  (90,
#   '0.028*"орудие" + 0.023*"корабль" + 0.019*"азербайджан" + 0.015*"кг" + 0.011*"15" + 0.010*"сша" + 0.010*"м" + 0.009*"длина" + 0.009*"секунда" + 0.008*"минута"'),
#  (91,
#   '0.043*"день" + 0.018*"праздник" + 0.017*"ассоциация" + 0.015*"птица" + 0.012*"международный" + 0.011*"национальный" + 0.009*"земля" + 0.009*"лесной" + 0.009*"семья" + 0.009*"возвращаться"'),
#  (9,
#   '0.033*"флот" + 0.030*"сила" + 0.026*"суд" + 0.017*"дело" + 0.016*"морской" + 0.016*"море" + 0.015*"боевой" + 0.015*"корабль" + 0.013*"южный" + 0.012*"отряд"'),
#  (8,
#   '0.034*"зимний_олимпийский" + 0.025*"страна" + 0.023*"игра_1988" + 0.021*"медаль" + 0.019*"ни_один" + 0.018*"боливия" + 0.018*"боливия_принимать" + 0.018*"не_завоевать" + 0.018*"история_но" + 0.016*"сеул_корея"'),
#  (7,
#   '0.037*"ссср" + 0.034*"украинский" + 0.021*"вооружённый_сила" + 0.017*"президент" + 0.016*"соревнование" + 0.015*"венгрия" + 0.014*"украина" + 0.013*"румыния" + 0.012*"оборона" + 0.012*"должность"'),
#  (6,
#   '0.011*"дисциплина" + 0.011*"зависимость_от" + 0.010*"журнал" + 0.009*"проходить_несколько" + 0.009*"хороший_экипаж" + 0.009*"сильный_экипаж" + 0.009*"ямайка" + 0.009*"ямайка_принимать" + 0.009*"г" + 0.009*"финал_a"'),
#  (5,
#   '0.062*"ни_один" + 0.062*"не_завоевать" + 0.061*"страна_представлять" + 0.058*"история_но" + 0.045*"медаль_сборная" + 0.041*"принимать_участие" + 0.028*"спортсмен" + 0.026*"тот_число" + 0.025*"соревнование_по" + 0.025*"женщина_принимать"'),
#  (4,
#   '0.037*"список" + 0.031*"объект" + 0.017*"российский" + 0.015*"компания" + 0.013*"2014_год" + 0.013*"акция" + 0.012*"число" + 0.011*"олимпийский" + 0.011*"7" + 0.010*"таблица"'),
#  (3,
#   '0.014*"москва" + 0.011*"пара" + 0.010*"сезон" + 0.008*"школа" + 0.008*"серия" + 0.008*"передача" + 0.008*"среднее" + 0.008*"команда" + 0.007*"федеральный" + 0.007*"очко"'),
#  (2,
#   '0.014*"написать" + 0.011*"литература" + 0.010*"жизнь" + 0.010*"умереть" + 0.010*"творчество" + 0.010*"роман" + 0.009*"семья" + 0.009*"деревня" + 0.008*"уезд" + 0.008*"книга"'),
#  (1,
#   '0.075*"село" + 0.039*"канада" + 0.027*"население" + 0.025*"река" + 0.022*"течение" + 0.017*"2001_год" + 0.016*"сельский_совет" + 0.014*"по_перепись" + 0.013*"харьковский_область" + 0.013*"на_расстояние"'),
#  (0,
#   '0.016*"альбом" + 0.011*"песня" + 0.008*"период" + 0.008*"культура" + 0.007*"регион" + 0.006*"около" + 0.006*"некоторый" + 0.005*"северный" + 0.005*"э" + 0.005*"национальный"')]

# %% [markdown]
# ### Model 3 (Ngramms + TFIDF)

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary2, )
corpus3 = tfidf[corpus2]

# %%
lda_ngramms_tfidf = gensim.models.LdaMulticore(corpus3, 
                                 100,
                                 alpha='asymmetric',
                                 id2word=dictionary2, 
                                 passes=10) 

lda_ngramms_tfidf.print_topics()
# Out:
# [(99,
#   '0.000*"собрание" + 0.000*"король" + 0.000*"депутат" + 0.000*"париж" + 0.000*"политический" + 0.000*"член" + 0.000*"принять" + 0.000*"революция" + 0.000*"клуб" + 0.000*"франция"'),
#  (98,
#   '0.001*"переход" + 0.001*"точка" + 0.001*"уровень" + 0.001*"механизм" + 0.001*"энергия" + 0.001*"свет" + 0.000*"температура" + 0.000*"помощь" + 0.000*"процесс" + 0.000*"вероятность"'),
#  (97,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (95,
#   '0.000*"дом" + 0.000*"священник" + 0.000*"английский" + 0.000*"жизнь" + 0.000*"1897_год" + 0.000*"оказываться" + 0.000*"так_как" + 0.000*"написать" + 0.000*"1896" + 0.000*"желать"'),
#  (96,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (94,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (93,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (92,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (91,
#   '0.000*"священник" + 0.000*"символ" + 0.000*"религиозный" + 0.000*"решение" + 0.000*"рим" + 0.000*"рядом" + 0.000*"самостоятельный" + 0.000*"свой_очередь" + 0.000*"расположение" + 0.000*"северный_часть"'),
#  (90,
#   '0.000*"реконструкция" + 0.000*"метр" + 0.000*"украина" + 0.000*"участок" + 0.000*"строительство" + 0.000*"область" + 0.000*"исторический" + 0.000*"2018_год" + 0.000*"железный_дорога" + 0.000*"старый"'),
#  (9,
#   '0.029*"сельсовет" + 0.011*"утверждение" + 0.008*"обращение" + 0.006*"эксперт" + 0.003*"мнение" + 0.002*"образоваться" + 0.001*"ошибка" + 0.001*"возникать" + 0.001*"село" + 0.000*"волость"'),
#  (8,
#   '0.010*"для_получение" + 0.001*"медицинский" + 0.001*"церковь" + 0.001*"представление" + 0.001*"сша" + 0.001*"данные" + 0.001*"личный" + 0.001*"строительство" + 0.001*"вид" + 0.001*"доллар"'),
#  (7,
#   '0.101*"фамилия" + 0.042*"известный" + 0.017*"параметр" + 0.007*"процесс" + 0.001*"рыба" + 0.001*"выход" + 0.000*"свидетель" + 0.000*"тело" + 0.000*"столетие" + 0.000*"лагерь"'),
#  (6,
#   '0.076*"станция" + 0.034*"математика" + 0.015*"линия" + 0.005*"ремонт" + 0.001*"сериал" + 0.001*"г" + 0.001*"сезон" + 0.001*"окончить" + 0.001*"норвежский" + 0.001*"задача"'),
#  (5,
#   '0.001*"150" + 0.001*"италия" + 0.001*"час" + 0.001*"младший" + 0.001*"участвовать" + 0.001*"схема" + 0.001*"армия" + 0.001*"партнёр" + 0.001*"творчество" + 0.001*"семья"'),
#  (4,
#   '0.069*"азербайджан" + 0.049*"роль" + 0.045*"театр" + 0.031*"музыкант" + 0.031*"юго-восток" + 0.031*"фильм" + 0.023*"актёр" + 0.020*"постановка" + 0.019*"ты" + 0.018*"кино"'),
#  (3,
#   '0.053*"лёгкий_атлетика" + 0.042*"э" + 0.042*"до_н" + 0.031*"фестиваль" + 0.029*"мяч" + 0.023*"студия" + 0.022*"кг" + 0.022*"анатолий" + 0.019*"выставка" + 0.019*"символ"'),
#  (2,
#   '0.081*"уезд" + 0.059*"село" + 0.043*"по_перепись" + 0.026*"харьковский_область" + 0.026*"губерния" + 0.023*"епархия" + 0.022*"волость" + 0.022*"2001_год" + 0.020*"термин" + 0.018*"посёлок"'),
#  (1,
#   '0.047*"сборная_страна" + 0.028*"третий_раз" + 0.023*"гонка" + 0.021*"игра_1996" + 0.020*"атланта_сша" + 0.016*"серебряный_медаль" + 0.015*"представлять" + 0.015*"боевой" + 0.015*"исключить" + 0.014*"1996"'),
#  (0,
#   '0.005*"страна_представлять" + 0.004*"не_завоевать" + 0.004*"история_но" + 0.004*"женщина" + 0.004*"спортсмен" + 0.004*"медаль_сборная" + 0.004*"игра" + 0.004*"вид" + 0.004*"г" + 0.003*"канада"')]

# %% [markdown]
# ### Model 4 (TFIDF)

# %%
tfidf = gensim.models.TfidfModel(corpus, id2word=dictionary1, )
corpus4 = tfidf[corpus]

# %%
lda_tfidf = gensim.models.LdaMulticore(corpus4, 
                                 100,
                                 alpha='asymmetric',
                                 id2word=dictionary1, 
                                 passes=10) 

lda_tfidf.print_topics()
# Out:
# [(99,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (98,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (97,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (95,
#   '0.001*"футбольный" + 0.001*"клуб" + 0.001*"команда" + 0.001*"сезон" + 0.000*"матч" + 0.000*"групповой" + 0.000*"чемпионат" + 0.000*"этап" + 0.000*"национальный" + 0.000*"первенство"'),
#  (96,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (94,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (93,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (91,
#   '0.000*"конечный" + 0.000*"круглый" + 0.000*"изобразить" + 0.000*"историк" + 0.000*"каменный" + 0.000*"комиссар" + 0.000*"конгресс" + 0.000*"здание" + 0.000*"красивый" + 0.000*"лишить"'),
#  (92,
#   '0.019*"дом" + 0.000*"собственность" + 0.000*"здание" + 0.000*"право" + 0.000*"суд" + 0.000*"сергей" + 0.000*"н" + 0.000*"москва" + 0.000*"жить" + 0.000*"участок"'),
#  (89,
#   '0.001*"режим" + 0.001*"париж" + 0.001*"атака" + 0.001*"император" + 0.001*"доступный" + 0.001*"1812" + 0.001*"игрок" + 0.001*"награда" + 0.001*"i" + 0.001*"19"'),
#  (9,
#   '0.023*"перейти" + 0.001*"тысяча" + 0.001*"забить" + 0.001*"зимой" + 0.001*"тыс" + 0.001*"лига" + 0.001*"южный" + 0.001*"53" + 0.001*"клуб" + 0.001*"2015"'),
#  (8,
#   '0.035*"соответственно" + 0.002*"кадр" + 0.001*"посёлок" + 0.001*"концерт" + 0.001*"культурный" + 0.001*"журнал" + 0.001*"in" + 0.001*"житель" + 0.001*"планета" + 0.001*"наука"'),
#  (7,
#   '0.092*"епископ" + 0.001*"священник" + 0.001*"актриса" + 0.001*"машина" + 0.001*"кнр" + 0.001*"норвегия" + 0.001*"епархия" + 0.001*"право" + 0.001*"экспериментальный" + 0.001*"критика"'),
#  (6,
#   '0.146*"1956" + 0.053*"птица" + 0.035*"дворец" + 0.023*"разобрать" + 0.022*"резерв" + 0.012*"1946" + 0.008*"фирма" + 0.001*"1940" + 0.001*"каменный" + 0.001*"острый"'),
#  (5,
#   '0.050*"иван" + 0.040*"ум" + 0.038*"автономный" + 0.026*"сибирь" + 0.025*"поход" + 0.024*"князь" + 0.023*"устройство" + 0.017*"дворянский" + 0.017*"испанский" + 0.013*"василий"'),
#  (4,
#   '0.105*"станция" + 0.084*"железнодорожный" + 0.046*"and" + 0.030*"россия" + 0.027*"дистанция" + 0.021*"дальний" + 0.019*"500" + 0.011*"секунда" + 0.002*"камера" + 0.001*"5-й"'),
#  (3,
#   '0.160*"департамент" + 0.073*"км²" + 0.047*"аргентина" + 0.037*"провинция" + 0.032*"плотность" + 0.025*"чел" + 0.022*"украинский" + 0.022*"впадать" + 0.019*"составить" + 0.018*"1998"'),
#  (2,
#   '0.067*"1988" + 0.047*"греция" + 0.039*"2004" + 0.037*"корея" + 0.031*"бронзовый" + 0.029*"1960" + 0.028*"бельгия" + 0.027*"серебряный" + 0.026*"1948" + 0.025*"мюнхен"'),
#  (1,
#   '0.024*"село" + 0.021*"атлетика" + 0.021*"спортсмен" + 0.019*"значение" + 0.018*"венесуэла" + 0.016*"посёлок" + 0.015*"км" + 0.014*"харьковский" + 0.014*"хутор" + 0.014*"1984"'),
#  (0,
#   '0.005*"остров" + 0.004*"уезд" + 0.003*"фильм" + 0.003*"канада" + 0.003*"клуб" + 0.003*"чемпионат" + 0.003*"зимний" + 0.002*"экипаж" + 0.002*"округ" + 0.002*"альбом"')]

# %% [markdown]
# ### Подсчет метрик

# %%
# lda perplexity

np.exp2(-lda.log_perplexity(corpus[:1000]))
# Out:
# 220.77176427964417

# %%
# lda coherence

topics = []
for topic_id, topic in lda.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictionary1, coherence='c_v')

coherence_model_lda.get_coherence()
# Out:
# 0.480947412078592

# %%
# lda_ngramms perplexity

np.exp2(-lda_ngramms.log_perplexity(corpus[:1000]))
# Out:
# 900.1441368375896

# %%
# lda_ngramms coherence (почему-то возвращается nan)

topics = []
for topic_id, topic in lda_ngramms.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictionary2, coherence='c_v')

coherence_model_lda.get_coherence()
# Out:
# nan

# %%
# lda_ngramms_tfidf perplexity

np.exp2(-lda_ngramms_tfidf.log_perplexity(corpus[:1000]))
# Out:
# 51464.38508137635

# %%
# lda_ngramms_tfidf coherence (и тут снова nan)

topics = []
for topic_id, topic in lda_ngramms_tfidf.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictionary2, coherence='u_mass')

# %%
# lda_tfidf perplexity

np.exp2(-lda_tfidf.log_perplexity(corpus[:1000]))
# Out:
# 463.0180261442919

# %%
# lda_tfidf coherence

topics = []
for topic_id, topic in lda_tfidf.show_topics(num_topics=100, formatted=False):
    topic = [word for word, _ in topic]
    topics.append(topic)

coherence_model_lda = gensim.models.CoherenceModel(topics=topics, 
                                                   texts=texts, 
                                                   dictionary=dictionary1, coherence='c_v')

coherence_model_lda.get_coherence()
# Out:
# 0.4293581021609177

# %% [markdown]
# **Выходит, наименьшая перплексия из всех 4-х моделей у самой первой без TFIDF и без нграммов (но скорее всего, здесь что-то не так). Когерентность (из тех, которе удалось посчитать) лучшая у модели 4 с TFIDF, хотя разница небольшая.**
